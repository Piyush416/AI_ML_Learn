# %%
import matplotlib.pyplot as plt

# %%
oscar_movies = [
    "The Dark Knight",
    "The Hurt Locker",
    "The King's Speech",
    "The Artist",
    "Argo"
]
year = [2008,2009,2010,2011,2012]
oscar_revenue = [1005, 170, 427, 133, 232]

# horizontal bar char 
# X axis = Values(oscar_revenue) and Y-axis = Categories(oscar_movies)
plt.barh(oscar_movies, oscar_revenue)  # plt.barh(Y,X)
plt.ylabel("Movies Name")
plt.xlabel("Revenue")
# Out:
# Text(0.5, 0, 'Revenue')
