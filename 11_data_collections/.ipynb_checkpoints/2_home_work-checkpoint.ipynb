# %%
# fetch the data from the any api and convert it into dataframe
import requests

# %%
URL = "https://bible-api.com/john+1"

# %%
res = requests.get(URL)
res
# Out:
# <Response [200]>

# %%
json_data = res.json()
# json_data

# %%
import pandas as pd
df = pd.json_normalize(json_data['verses']);
df
# Out:
#    book_id book_name  chapter  verse  \
# 0      JHN      John        1      1
# 1      JHN      John        1      2
# 2      JHN      John        1      3
# 3      JHN      John        1      4
# 4      JHN      John        1      5
# 5      JHN      John        1      6
# 6      JHN      John        1      7
# 7      JHN      John        1      8
# 8      JHN      John        1      9
# 9      JHN      John        1     10
# 10     JHN      John        1     11
# 11     JHN      John        1     12
# 12     JHN      John        1     13
# 13     JHN      John        1     14
# 14     JHN      John        1     15
# 15     JHN      John        1     16
# 16     JHN      John        1     17
# 17     JHN      John        1     18
# 18     JHN      John        1     19
# 19     JHN      John        1     20
# 20     JHN      John        1     21
# 21     JHN      John        1     22
# 22     JHN      John        1     23
# 23     JHN      John        1     24
# ...
