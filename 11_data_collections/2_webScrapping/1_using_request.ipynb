# %%
# Web scraping Sandbox search in google 
# https://www.scrapethissite.com/pages/simple/ this is illegal website to perform web scraping

# %%
import requests

# %%
URL = "https://www.scrapethissite.com/pages/simple/"

# %%
res = requests.get(URL)

# %%
# if res.status_code == 200:
#     print(res.text)

# %%
# give the html code
# res.text 

# raw data of response
# res.content

# give the headers
# res.headers

# %%
# save the html data to data1.html file in scraped_data folder

with open("scraped_data/data1.html", "w") as f:
    f.write(res.text)
