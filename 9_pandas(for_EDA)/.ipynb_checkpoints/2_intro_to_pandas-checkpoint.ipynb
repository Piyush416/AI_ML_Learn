# %% [markdown]
# # Introduction To Pandas

# %%
# numpy -> to compuling numerical value
# panda -> is build top of numpy

# %% [markdown]
# [Documentation of panda](https://pandas.pydata.org/docs/user_guide/index.html#user-guide)
# - as a engineer and developer make a mindset that I can learn anythink from documentation.
# - as a developer build habit to learn and understand from the documentation.
# - whenever new technology come all think is given in documentation.

# %%
# data structure
# numpy ->  ndarray
# pandas -> series, dataframes
# series ->     1d labelled array
# dataframes -> 2d labelled array

# %%
import pandas as pd
info = {
    "Name" : ["Piyush", "Shree", "Shraddha"],
    "CGPA" : [9.5, 9.3, 9.1]
}
df = pd.DataFrame(info)
df
# Out:
#        Name  CGPA
# 0    Piyush   9.5
# 1     Shree   9.3
# 2  Shraddha   9.1

# %%
# this 0 , 1, 2 is called labelled (by default it is based on indexing)
# we can also change the labelled
